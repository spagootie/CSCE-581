# %% [markdown]
# # Introduction
#
# In this notebook, we present data analysis on Chatbot Arena data collected from https://arena.lmsys.org.
#
# We explain different Elo calculation methods (online Elo and Bradley-Terry model) for model ranking.
#
# To view the latest leaderboard, see https://huggingface.co/spaces/lmsys/chatbot-arena-leaderboard.

# %%
import sys
# !{sys.executable} -m pip install gdown numpy pandas plotly tqdm requests ipython nbformat

from collections import defaultdict
import json, math, gdown
import numpy as np
import pandas as pd
import plotly.express as px
from tqdm import tqdm
import requests
pd.options.display.float_format = '{:.2f}'.format
# Out:
# Requirement already satisfied: gdown in /home/madison/.pythonenv/lib/python3.14/site-packages (6.0.0)
# Requirement already satisfied: numpy in /home/madison/.pythonenv/lib/python3.14/site-packages (2.4.4)
# Requirement already satisfied: pandas in /home/madison/.pythonenv/lib/python3.14/site-packages (3.0.2)
# Requirement already satisfied: plotly in /home/madison/.pythonenv/lib/python3.14/site-packages (6.7.0)
# Requirement already satisfied: tqdm in /home/madison/.pythonenv/lib/python3.14/site-packages (4.67.3)
# Requirement already satisfied: requests in /home/madison/.pythonenv/lib/python3.14/site-packages (2.33.0)
# Requirement already satisfied: ipython in /home/madison/.pythonenv/lib/python3.14/site-packages (9.12.0)
# Requirement already satisfied: nbformat in /home/madison/.pythonenv/lib/python3.14/site-packages (5.10.4)
# Requirement already satisfied: beautifulsoup4 in /home/madison/.pythonenv/lib/python3.14/site-packages (from gdown) (4.14.3)
# Requirement already satisfied: filelock in /home/madison/.pythonenv/lib/python3.14/site-packages (from gdown) (3.29.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/madison/.pythonenv/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: narwhals>=1.15.1 in /home/madison/.pythonenv/lib/python3.14/site-packages (from plotly) (2.20.0)
# Requirement already satisfied: packaging in /home/madison/.pythonenv/lib/python3.14/site-packages (from plotly) (26.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/madison/.pythonenv/lib/python3.14/site-packages (from requests) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/madison/.pythonenv/lib/python3.14/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/madison/.pythonenv/lib/python3.14/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /home/madison/.pythonenv/lib/python3.14/site-packages (from requests) (2026.2.25)
# Requirement already satisfied: decorator>=5.1.0 in /home/madison/.pythonenv/lib/python3.14/site-packages (from ipython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/madison/.pythonenv/lib/python3.14/site-packages (from ipython) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /home/madison/.pythonenv/lib/python3.14/site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /home/madison/.pythonenv/lib/python3.14/site-packages (from ipython) (0.2.1)
# Requirement already satisfied: pexpect>4.6 in /home/madison/.pythonenv/lib/python3.14/site-packages (from ipython) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/madison/.pythonenv/lib/python3.14/site-packages (from ipython) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /home/madison/.pythonenv/lib/python3.14/site-packages (from ipython) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /home/madison/.pythonenv/lib/python3.14/site-packages (from ipython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/madison/.pythonenv/lib/python3.14/site-packages (from ipython) (5.14.3)
# Requirement already satisfied: wcwidth in /home/madison/.pythonenv/lib/python3.14/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython) (0.6.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/madison/.pythonenv/lib/python3.14/site-packages (from nbformat) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/madison/.pythonenv/lib/python3.14/site-packages (from nbformat) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/madison/.pythonenv/lib/python3.14/site-packages (from nbformat) (5.9.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/madison/.pythonenv/lib/python3.14/site-packages (from jedi>=0.18.2->ipython) (0.8.6)
# Requirement already satisfied: attrs>=22.2.0 in /home/madison/.pythonenv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/madison/.pythonenv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/madison/.pythonenv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/madison/.pythonenv/lib/python3.14/site-packages (from jsonschema>=2.6->nbformat) (0.30.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/madison/.pythonenv/lib/python3.14/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat) (4.9.6)
# Requirement already satisfied: ptyprocess>=0.5 in /home/madison/.pythonenv/lib/python3.14/site-packages (from pexpect>4.6->ipython) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/madison/.pythonenv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /home/madison/.pythonenv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/madison/.pythonenv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython) (3.0.1)
# Requirement already satisfied: pure-eval in /home/madison/.pythonenv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython) (0.2.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /home/madison/.pythonenv/lib/python3.14/site-packages (from beautifulsoup4->gdown) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/madison/.pythonenv/lib/python3.14/site-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /home/madison/.pythonenv/lib/python3.14/site-packages (from requests[socks]->gdown) (1.7.1)
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# # Obtaining and Cleaning the Tournament Data
# We are hosting the initial tournament results as a JSON file on Google Drive. We use the `gdown` function to download the data. The data contains all the battels and voting results collected for ranking models.

# %%
# we use the latest data
url = "https://storage.googleapis.com/arena_external_data/public/clean_battle_20240814_public.json"
response = requests.get(url)

with open('local_file_name.json', 'wb') as file:
    file.write(response.content)

# load the JSON data from the local file
with open('local_file_name.json', 'r') as file:
    battles = pd.read_json(file).sort_values(ascending=True, by=["tstamp"])

# %%
battles
# Out:
#                          model_a                     model_b         winner  \
# 0                     chatglm-6b                   koala-13b        model_b
# 1               oasst-pythia-12b                  alpaca-13b            tie
# 2                      koala-13b            oasst-pythia-12b        model_b
# 3                     vicuna-13b            oasst-pythia-12b        model_b
# 4                     vicuna-13b                   koala-13b        model_a
# ...                          ...                         ...            ...
# 1799986      llama-3-8b-instruct           chatgpt-4o-latest        model_a
# 1799987        gpt-4o-2024-08-06  claude-3-5-sonnet-20240620        model_a
# 1799988    llama-3.1-8b-instruct         reka-flash-20240722  tie (bothbad)
# 1799989  gemini-1.5-pro-api-0514     claude-3-haiku-20240307        model_a
# 1799990  llama-3.1-405b-instruct  claude-3-5-sonnet-20240620  tie (bothbad)
#
#                                     judge  turn  anony language        tstamp  \
# 0        2e9c29aa140b8e50643235eab01dc9ea     1   True  English 1682351591.13
# 1        2e9c29aa140b8e50643235eab01dc9ea     1   True  English 1682351654.67
# 2        2e9c29aa140b8e50643235eab01dc9ea     1   True  English 1682351708.94
# 3        2e9c29aa140b8e50643235eab01dc9ea     1   True  English 1682351785.19
# 4        2e9c29aa140b8e50643235eab01dc9ea     1   True  English 1682351891.66
# ...                                   ...   ...    ...      ...           ...
# 1799986  1f08bb8a2f8f77ef1dd3e2f91c4214f2     1   True  English 1723665137.57
# 1799987  211cc2f9ea2b5846cfa3c373f32db8f4     1   True  Russian 1723665139.77
# 1799988  1bf5cd833334692589920215e6a5ad84     1   True   Polish 1723665143.79
# 1799989  41893b64a23df36ec2e2acbc7aa78def     2   True  English 1723665163.09
# 1799990  1f08bb8a2f8f77ef1dd3e2f91c4214f2     1   True  English 1723665173.41
#
#                                              conv_metadata  is_code  \
# 0        {'sum_user_tokens': 10, 'sum_assistant_a_token...     True
# 1        {'sum_user_tokens': 11, 'sum_assistant_a_token...    False
# 2        {'sum_user_tokens': 10, 'sum_assistant_a_token...    False
# 3        {'sum_user_tokens': 9, 'sum_assistant_a_tokens...    False
# 4        {'sum_user_tokens': 5, 'sum_assistant_a_tokens...    False
# ...                                                    ...      ...
# 1799986  {'sum_user_tokens': 18, 'sum_assistant_a_token...    False
# 1799987  {'sum_user_tokens': 436, 'sum_assistant_a_toke...    False
# 1799988  {'sum_user_tokens': 28, 'sum_assistant_a_token...    False
# 1799989  {'sum_user_tokens': 42, 'sum_assistant_a_token...    False
# 1799990  {'sum_user_tokens': 8, 'sum_assistant_a_tokens...    False
#
#          is_refusal                              dedup_tag  \
# 0             False  {'high_freq': False, 'sampled': True}
# 1             False  {'high_freq': False, 'sampled': True}
# 2             False  {'high_freq': False, 'sampled': True}
# 3             False  {'high_freq': False, 'sampled': True}
# 4              True  {'high_freq': False, 'sampled': True}
# ...             ...                                    ...
# 1799986       False  {'high_freq': False, 'sampled': True}
# 1799987       False  {'high_freq': False, 'sampled': True}
# 1799988       False  {'high_freq': False, 'sampled': True}
# 1799989       False  {'high_freq': False, 'sampled': True}
# 1799990        True  {'high_freq': False, 'sampled': True}
#
#                                               category_tag
# 0        {'if_v0.1': {'if': False, 'score': 1}, 'math_v...
# 1        {'if_v0.1': {'if': False, 'score': 0}, 'math_v...
# 2        {'if_v0.1': {'if': False, 'score': 0}, 'math_v...
# 3        {'if_v0.1': {'if': False, 'score': 1}, 'math_v...
# 4        {'if_v0.1': {'if': False, 'score': 0}, 'math_v...
# ...                                                    ...
# 1799986  {'if_v0.1': {'if': False, 'score': 1}, 'math_v...
# 1799987  {'if_v0.1': {'if': False, 'score': 3}, 'math_v...
# 1799988  {'if_v0.1': {'if': False, 'score': 2}, 'math_v...
# 1799989  {'if_v0.1': {'if': False, 'score': 1}, 'math_v...
# 1799990  {'if_v0.1': {'if': False, 'score': 1}, 'math_v...
#
# [1799991 rows x 13 columns]

# %%
# we use anony battles only for leaderboard
battles = battles[battles["anony"] == True]

# we de-duplicate top 0.1% redudant prompts
# see https://lmsys.org/blog/2024-05-17-category-hard/#note-enhancing-quality-through-de-duplication
print("Before dedup: ", len(battles))
battles = battles[battles["dedup_tag"].apply(lambda x: x.get("sampled", False))]
print("After dedup: ", len(battles))
# Out:
# Before dedup:  1799991
# After dedup:  1670250

# %% [markdown]
# # Exploratory Analysis
#
# Before computing the Elo ratings, we first conduct some basic exploratory analysis to highlight a few key properties and caveates with this data.

# %% [markdown]
# ## Statistics
#
# We allowed the user to declare a tie between the pairs of models.  To collect additional data, later in the tournament we also allowed the user to declare a tie in which both models were bad.  There were a significant portion of tied outcomes.

# %%
fig = px.bar(battles["winner"].value_counts(),
             title="Counts of Battle Outcomes", text_auto=True, height=400)
fig.update_layout(xaxis_title="Battle Outcome", yaxis_title="Count",
                  showlegend=False)
fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.mypipenv/lib/python3.14/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'variable=count<br>winner=%{x}<br>value=%{y}<extra></extra>',
#               'legendgroup': 'count',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': 'count',
#               'orientation': 'v',
#               'showlegend': True,
#               'textposition': 'auto',
#               'texttemplate': '%{y}',
#               'type': 'bar',
#               'x': array(['model_b', 'model_a', 'tie (bothbad)', 'tie'], dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': 'mmcIAFlJCABWgQQAIUoEAA==', 'dtype': 'i4'},
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'height': 400,
#                'legend': {'title': {'text': 'variable'}, 'tracegroupgap': 0},
#                'showlegend': False,
#                'template': '...',
#                'title': {'text': 'Counts of Battle Outcomes'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'Battle Outcome'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Count'}}}
# })

# %%
battles_no_ties = battles[~battles["winner"].str.contains("tie")]

# %% [markdown]
# ## Non-uniform Model Frequency
#
# The model frequency is not uniform because of the follwoing reasons:
# - Several different matching and sampling algorithms were used. We employed uniform sampling as well as weighted sampling methods, which assign greater weights to better models.
# - Some new models were added later.

# %%
fig = px.bar(pd.concat([battles["model_a"], battles["model_b"]]).value_counts(),
             title="Battle Count for Each Model", text_auto=True)
fig.update_layout(xaxis_title="model", yaxis_title="Battle Count", height=400,
                  showlegend=False)
fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.mypipenv/lib/python3.14/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'variable=count<br>index=%{x}<br>value=%{y}<extra></extra>',
#               'legendgroup': 'count',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': 'count',
#               'orientation': 'v',
#               'showlegend': True,
#               'textposition': 'auto',
#               'texttemplate': '%{y}',
#               'type': 'bar',
#               'x': array(['llama-3-70b-instruct', 'claude-3-opus-20240229',
#                           'claude-3-sonnet-20240229', 'claude-3-haiku-20240307',
#                           'llama-3-8b-instruct', 'gpt-4-1106-preview', 'gpt-4-0613',
#                           'gpt-4-0125-preview', 'gpt-4-turbo-2024-04-09', 'command-r-plus',
#                           'gpt-4o-2024-05-13', 'mixtral-8x7b-instruct-v0.1',
#                           'gemini-1.5-pro-api-0514', 'gpt-3.5-turbo-0125', 'mistral-large-2402',
#                           'reka-core-20240501', 'command-r', 'gemini-1.5-flash-api-0514',
#                           'gpt-4-0314', 'gemini-1.5-pro-api-0409-preview', 'gemini-advanced-0514',
#                           'yi-large-preview', 'mixtral-8x22b-instruct-v0.1',
#                           'claude-3-5-sonnet-20240620', 'qwen1.5-72b-chat', 'llama-2-70b-chat',
#                           'gpt-3.5-turbo-0613', 'claude-2.1', 'mistral-medium',
#                           'qwen2-72b-instruct', 'snowflake-arctic-instruct',
#                           'dbrx-instruct-preview', 'gemma-2-27b-it', 'qwen1.5-110b-chat',
#                           'reka-flash-21b-20240226', 'qwen-max-0428', 'gemma-2-9b-it',
#                           'yi-1.5-34b-chat', 'gemma-1.1-7b-it', 'vicuna-33b', 'qwen1.5-32b-chat',
#                           'phi-3-medium-4k-instruct', 'phi-3-mini-128k-instruct', 'claude-1',
#                           'phi-3-mini-4k-instruct', 'nemotron-4-340b-instruct',
#                           'claude-instant-1', 'reka-flash-preview-20240611',
#                           'mistral-7b-instruct-v0.2', 'gemini-1.5-pro-exp-0801', 'vicuna-13b',
#                           'llama-2-13b-chat', 'gpt-4o-mini-2024-07-18', 'llama-3.1-405b-instruct',
#                           'gemini-pro-dev-api', 'qwen1.5-14b-chat', 'phi-3-small-8k-instruct',
#                           'gpt-3.5-turbo-1106', 'yi-large', 'starling-lm-7b-beta',
#                           'deepseek-v2-api-0628', 'reka-flash-21b-20240226-online', 'yi-34b-chat',
#                           'deepseek-coder-v2', 'llama-2-7b-chat', 'chatgpt-4o-latest',
#                           'llama-3.1-70b-instruct', 'openchat-3.5-0106', 'claude-2.0',
#                           'llama-3.1-8b-instruct', 'mistral-next', 'bard-jan-24-gemini-pro',
#                           'mistral-large-2407', 'athene-70b-0725', 'gemma-1.1-2b-it',
#                           'zephyr-7b-beta', 'gemma-2-2b-it', 'phi-3-mini-4k-instruct-june-2024',
#                           'starling-lm-7b-alpha', 'glm-4-0520', 'gpt-4o-2024-08-06',
#                           'gemma-7b-it', 'mistral-7b-instruct', 'palm-2', 'wizardlm-70b',
#                           'openchat-3.5', 'qwen1.5-4b-chat', 'glm-4-0116',
#                           'codellama-34b-instruct', 'wizardlm-13b', 'reka-flash-20240722',
#                           'koala-13b', 'vicuna-7b', 'reka-core-20240722', 'pplx-70b-online',
#                           'tulu-2-dpo-70b', 'gemini-pro', 'olmo-7b-instruct', 'oasst-pythia-12b',
#                           'pplx-7b-online', 'alpaca-13b', 'gpt-3.5-turbo-0314',
#                           'stripedhyena-nous-7b', 'openhermes-2.5-mistral-7b', 'qwen-14b-chat',
#                           'chatglm-6b', 'deepseek-llm-67b-chat', 'RWKV-4-Raven-14B',
#                           'gemma-2b-it', 'qwen1.5-7b-chat', 'zephyr-orpo-141b-A35b-v0.1',
#                           'chatglm3-6b', 'fastchat-t5-3b', 'solar-10.7b-instruct-v1.0',
#                           'mpt-7b-chat', 'deepseek-coder-v2-0724',
#                           'nous-hermes-2-mixtral-8x7b-dpo', 'llama2-70b-steerlm-chat',
#                           'dolly-v2-12b', 'stablelm-tuned-alpha-7b', 'guanaco-33b', 'chatglm2-6b',
#                           'mpt-30b-chat', 'llama-13b', 'zephyr-7b-alpha', 'gpt4all-13b-snoozy',
#                           'dolphin-2.2.1-mistral-7b', 'falcon-180b-chat',
#                           'codellama-70b-instruct'], dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': ('I3gCAChhAgDSuQEAQK0BAFyiAQBIaQ' ... 'kAABcHAAD7BgAAsgYAAC0FAACpBAAA'),
#                     'dtype': 'i4'},
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'height': 400,
#                'legend': {'title': {'text': 'variable'}, 'tracegroupgap': 0},
#                'showlegend': False,
#                'template': '...',
#                'title': {'text': 'Battle Count for Each Model'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'model'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Battle Count'}}}
# })

# %% [markdown]
# We examing the number of pairings for each combination of models.

# %%
def visualize_battle_count(battles, title, show_num_models=30):
    ptbl = pd.pivot_table(battles, index="model_a", columns="model_b", aggfunc="size",
                          fill_value=0)
    battle_counts = ptbl + ptbl.T
    ordering = battle_counts.sum().sort_values(ascending=False).index
    ordering = ordering[:show_num_models]
    fig = px.imshow(battle_counts.loc[ordering, ordering],
                    title=title, text_auto=True)
    fig.update_layout(xaxis_title="Model B",
                      yaxis_title="Model A",
                      xaxis_side="top", height=800, width=800,
                      title_y=0.07, title_x=0.5,
                      font=dict(size=10))
    fig.update_traces(hovertemplate=
                      "Model A: %{y}<br>Model B: %{x}<br>Count: %{z}<extra></extra>")
    return fig

fig = visualize_battle_count(battles, title="Battle Count of Each Combination of Models", show_num_models=30)
fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.mypipenv/lib/python3.14/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'coloraxis': 'coloraxis',
#               'hovertemplate': 'Model A: %{y}<br>Model B: %{x}<br>Count: %{z}<extra></extra>',
#               'name': '0',
#               'texttemplate': '%{z}',
#               'type': 'heatmap',
#               'x': array(['llama-3-70b-instruct', 'claude-3-opus-20240229',
#                           'claude-3-sonnet-20240229', 'claude-3-haiku-20240307',
#                           'llama-3-8b-instruct', 'gpt-4-1106-preview', 'gpt-4-0613',
#                           'gpt-4-0125-preview', 'gpt-4-turbo-2024-04-09', 'command-r-plus',
#                           'gpt-4o-2024-05-13', 'mixtral-8x7b-instruct-v0.1',
#                           'gemini-1.5-pro-api-0514', 'gpt-3.5-turbo-0125', 'mistral-large-2402',
#                           'reka-core-20240501', 'command-r', 'gemini-1.5-flash-api-0514',
#                           'gpt-4-0314', 'gemini-1.5-pro-api-0409-preview', 'gemini-advanced-0514',
#                           'yi-large-preview', 'mixtral-8x22b-instruct-v0.1',
#                           'claude-3-5-sonnet-20240620', 'qwen1.5-72b-chat', 'llama-2-70b-chat',
#                           'gpt-3.5-turbo-0613', 'claude-2.1', 'mistral-medium',
#                           'qwen2-72b-instruct'], dtype=object),
#               'xaxis': 'x',
#               'y': array(['llama-3-70b-instruct', 'claude-3-opus-20240229',
#                           'claude-3-sonnet-20240229', 'claude-3-haiku-20240307',
#                           'llama-3-8b-instruct', 'gpt-4-1106-preview', 'gpt-4-0613',
#                           'gpt-4-0125-preview', 'gpt-4-turbo-2024-04-09', 'command-r-plus',
#                           'gpt-4o-2024-05-13', 'mixtral-8x7b-instruct-v0.1',
#                           'gemini-1.5-pro-api-0514', 'gpt-3.5-turbo-0125', 'mistral-large-2402',
#                           'reka-core-20240501', 'command-r', 'gemini-1.5-flash-api-0514',
#                           'gpt-4-0314', 'gemini-1.5-pro-api-0409-preview', 'gemini-advanced-0514',
#                           'yi-large-preview', 'mixtral-8x22b-instruct-v0.1',
#                           'claude-3-5-sonnet-20240620', 'qwen1.5-72b-chat', 'llama-2-70b-chat',
#                           'gpt-3.5-turbo-0613', 'claude-2.1', 'mistral-medium',
#                           'qwen2-72b-instruct'], dtype=object),
#               'yaxis': 'y',
#               'z': {'bdata': ('AADOKWwUVRNdM40LJwtFEAUe/hJzF0' ... 'AAAJ8EpwPPAUsDhAAAAAAAAAAAAAAA'),
#                     'dtype': 'i2',
#                     'shape': '30, 30'}}],
#     'layout': {'coloraxis': {'colorscale': [[0.0, '#0d0887'], [0.1111111111111111,
#                                             '#46039f'], [0.2222222222222222,
#                                             '#7201a8'], [0.3333333333333333,
#                                             '#9c179e'], [0.4444444444444444,
#                                             '#bd3786'], [0.5555555555555556,
#                                             '#d8576b'], [0.6666666666666666,
#                                             '#ed7953'], [0.7777777777777778,
#                                             '#fb9f3a'], [0.8888888888888888,
#                                             '#fdca26'], [1.0, '#f0f921']]},
#                'font': {'size': 10},
#                'height': 800,
#                'template': '...',
#                'title': {'text': 'Battle Count of Each Combination of Models', 'x': 0.5, 'y': 0.07},
#                'width': 800,
#                'xaxis': {'anchor': 'y',
#                          'constrain': 'domain',
#                          'domain': [0.0, 1.0],
#                          'scaleanchor': 'y',
#                          'side': 'top',
#                          'title': {'text': 'Model B'}},
#                'yaxis': {'anchor': 'x',
#                          'autorange': 'reversed',
#                          'constrain': 'domain',
#                          'domain': [0.0, 1.0],
#                          'title': {'text': 'Model A'}}}
# })

# %% [markdown]
# ### Battles Excluding Ties

# %%
visualize_battle_count(battles_no_ties, "Battle Count for Each Combination of Models (without Ties)")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.mypipenv/lib/python3.14/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'coloraxis': 'coloraxis',
#               'hovertemplate': 'Model A: %{y}<br>Model B: %{x}<br>Count: %{z}<extra></extra>',
#               'name': '0',
#               'texttemplate': '%{z}',
#               'type': 'heatmap',
#               'x': array(['claude-3-opus-20240229', 'llama-3-70b-instruct',
#                           'claude-3-sonnet-20240229', 'claude-3-haiku-20240307',
#                           'llama-3-8b-instruct', 'gpt-4-1106-preview', 'gpt-4-0613',
#                           'gpt-4-0125-preview', 'gpt-4-turbo-2024-04-09', 'command-r-plus',
#                           'gpt-4o-2024-05-13', 'mixtral-8x7b-instruct-v0.1',
#                           'gemini-1.5-pro-api-0514', 'gpt-3.5-turbo-0125', 'mistral-large-2402',
#                           'reka-core-20240501', 'gemini-1.5-pro-api-0409-preview', 'gpt-4-0314',
#                           'command-r', 'gemini-1.5-flash-api-0514', 'gemini-advanced-0514',
#                           'yi-large-preview', 'mixtral-8x22b-instruct-v0.1',
#                           'claude-3-5-sonnet-20240620', 'gpt-3.5-turbo-0613', 'qwen1.5-72b-chat',
#                           'claude-2.1', 'llama-2-70b-chat', 'mistral-medium',
#                           'snowflake-arctic-instruct'], dtype=object),
#               'xaxis': 'x',
#               'y': array(['claude-3-opus-20240229', 'llama-3-70b-instruct',
#                           'claude-3-sonnet-20240229', 'claude-3-haiku-20240307',
#                           'llama-3-8b-instruct', 'gpt-4-1106-preview', 'gpt-4-0613',
#                           'gpt-4-0125-preview', 'gpt-4-turbo-2024-04-09', 'command-r-plus',
#                           'gpt-4o-2024-05-13', 'mixtral-8x7b-instruct-v0.1',
#                           'gemini-1.5-pro-api-0514', 'gpt-3.5-turbo-0125', 'mistral-large-2402',
#                           'reka-core-20240501', 'gemini-1.5-pro-api-0409-preview', 'gpt-4-0314',
#                           'command-r', 'gemini-1.5-flash-api-0514', 'gemini-advanced-0514',
#                           'yi-large-preview', 'mixtral-8x22b-instruct-v0.1',
#                           'claude-3-5-sonnet-20240620', 'gpt-3.5-turbo-0613', 'qwen1.5-72b-chat',
#                           'claude-2.1', 'llama-2-70b-chat', 'mistral-medium',
#                           'snowflake-arctic-instruct'], dtype=object),
#               'yaxis': 'y',
#               'z': {'bdata': ('AAAMHMwVyxFXD1IKqQsVEmIPAhAvDG' ... 'C4ALgA3gDmAj8AAACqAAAAUABSAAAA'),
#                     'dtype': 'i2',
#                     'shape': '30, 30'}}],
#     'layout': {'coloraxis': {'colorscale': [[0.0, '#0d0887'], [0.1111111111111111,
#                                             '#46039f'], [0.2222222222222222,
#                                             '#7201a8'], [0.3333333333333333,
#                                             '#9c179e'], [0.4444444444444444,
#                                             '#bd3786'], [0.5555555555555556,
#                                             '#d8576b'], [0.6666666666666666,
#                                             '#ed7953'], [0.7777777777777778,
#                                             '#fb9f3a'], [0.8888888888888888,
#                                             '#fdca26'], [1.0, '#f0f921']]},
#                'font': {'size': 10},
#                'height': 800,
#                'template': '...',
#                'title': {'text': 'Battle Count for Each Combination of Models (without Ties)', 'x': 0.5, 'y': 0.07},
#                'width': 800,
#                'xaxis': {'anchor': 'y',
#                          'constrain': 'domain',
#                          'domain': [0.0, 1.0],
#                          'scaleanchor': 'y',
#                          'side': 'top',
#                          'title': {'text': 'Model B'}},
#                'yaxis': {'anchor': 'x',
#                          'autorange': 'reversed',
#                          'constrain': 'domain',
#                          'domain': [0.0, 1.0],
#                          'title': {'text': 'Model A'}}}
# })

# %% [markdown]
# ### Counting Ties

# %%
visualize_battle_count(battles[battles['winner'].str.contains("tie")], "Tie Count for Each Combination of Models")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.mypipenv/lib/python3.14/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'coloraxis': 'coloraxis',
#               'hovertemplate': 'Model A: %{y}<br>Model B: %{x}<br>Count: %{z}<extra></extra>',
#               'name': '0',
#               'texttemplate': '%{z}',
#               'type': 'heatmap',
#               'x': array(['llama-3-70b-instruct', 'claude-3-opus-20240229', 'llama-3-8b-instruct',
#                           'claude-3-haiku-20240307', 'claude-3-sonnet-20240229', 'gpt-4-0613',
#                           'gpt-4-1106-preview', 'gpt-4-turbo-2024-04-09', 'command-r-plus',
#                           'gpt-4-0125-preview', 'gpt-4o-2024-05-13', 'mixtral-8x7b-instruct-v0.1',
#                           'gemini-1.5-pro-api-0514', 'gpt-3.5-turbo-0125', 'reka-core-20240501',
#                           'mistral-large-2402', 'gemini-1.5-flash-api-0514', 'command-r',
#                           'yi-large-preview', 'gpt-4-0314', 'mixtral-8x22b-instruct-v0.1',
#                           'gemini-advanced-0514', 'gemini-1.5-pro-api-0409-preview',
#                           'claude-3-5-sonnet-20240620', 'qwen1.5-72b-chat', 'llama-2-70b-chat',
#                           'qwen2-72b-instruct', 'gpt-3.5-turbo-0613', 'snowflake-arctic-instruct',
#                           'dbrx-instruct-preview'], dtype=object),
#               'xaxis': 'x',
#               'y': array(['llama-3-70b-instruct', 'claude-3-opus-20240229', 'llama-3-8b-instruct',
#                           'claude-3-haiku-20240307', 'claude-3-sonnet-20240229', 'gpt-4-0613',
#                           'gpt-4-1106-preview', 'gpt-4-turbo-2024-04-09', 'command-r-plus',
#                           'gpt-4-0125-preview', 'gpt-4o-2024-05-13', 'mixtral-8x7b-instruct-v0.1',
#                           'gemini-1.5-pro-api-0514', 'gpt-3.5-turbo-0125', 'reka-core-20240501',
#                           'mistral-large-2402', 'gemini-1.5-flash-api-0514', 'command-r',
#                           'yi-large-preview', 'gpt-4-0314', 'mixtral-8x22b-instruct-v0.1',
#                           'gemini-advanced-0514', 'gemini-1.5-pro-api-0409-preview',
#                           'claude-3-5-sonnet-20240620', 'qwen1.5-72b-chat', 'llama-2-70b-chat',
#                           'qwen2-72b-instruct', 'gpt-3.5-turbo-0613', 'snowflake-arctic-instruct',
#                           'dbrx-instruct-preview'], dtype=object),
#               'yaxis': 'y',
#               'z': {'bdata': ('AADCDUQXuQYaB5UDzQPbCfAGTwVhB1' ... 'C5AI0ASABMACIAlgALAkgAAAAsBAAA'),
#                     'dtype': 'i2',
#                     'shape': '30, 30'}}],
#     'layout': {'coloraxis': {'colorscale': [[0.0, '#0d0887'], [0.1111111111111111,
#                                             '#46039f'], [0.2222222222222222,
#                                             '#7201a8'], [0.3333333333333333,
#                                             '#9c179e'], [0.4444444444444444,
#                                             '#bd3786'], [0.5555555555555556,
#                                             '#d8576b'], [0.6666666666666666,
#                                             '#ed7953'], [0.7777777777777778,
#                                             '#fb9f3a'], [0.8888888888888888,
#                                             '#fdca26'], [1.0, '#f0f921']]},
#                'font': {'size': 10},
#                'height': 800,
#                'template': '...',
#                'title': {'text': 'Tie Count for Each Combination of Models', 'x': 0.5, 'y': 0.07},
#                'width': 800,
#                'xaxis': {'anchor': 'y',
#                          'constrain': 'domain',
#                          'domain': [0.0, 1.0],
#                          'scaleanchor': 'y',
#                          'side': 'top',
#                          'title': {'text': 'Model B'}},
#                'yaxis': {'anchor': 'x',
#                          'autorange': 'reversed',
#                          'constrain': 'domain',
#                          'domain': [0.0, 1.0],
#                          'title': {'text': 'Model A'}}}
# })

# %% [markdown]
# ## Inferred Language
#
# We also inferred the language for each conversation using `polyglot` package. This is just an estimate but will help guide future analysis.  The vast majority of conversations were in English.

# %%
lang_count = battles["language"].value_counts()
lang_count = lang_count.drop(index=("unknown"))

# %%
topk = 15
fig = px.bar(lang_count.head(topk),
             title=f"Battle Counts for the Top {topk} Languages",
             text_auto=True, height=400, log_y=True)
fig.update_layout(xaxis_title="Language", yaxis_title="Count", showlegend=False)
fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.mypipenv/lib/python3.14/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'variable=count<br>language=%{x}<br>value=%{y}<extra></extra>',
#               'legendgroup': 'count',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': 'count',
#               'orientation': 'v',
#               'showlegend': True,
#               'textposition': 'auto',
#               'texttemplate': '%{y}',
#               'type': 'bar',
#               'x': array(['English', 'Chinese', 'Russian', 'German', 'Korean', 'Japanese',
#                           'French', 'Spanish', 'Portuguese', 'Vietnamese', 'Italian', 'Persian',
#                           'Czech', 'Polish', 'Arabic'], dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': 'OUsPAFSzAgD5NgIA2cEAAI6QAABJhgAAXm4AAOtrAAA7QQAAFTUAACQ0AAB/JAAAKB0AANYZAABgFAAA',
#                     'dtype': 'i4'},
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'height': 400,
#                'legend': {'title': {'text': 'variable'}, 'tracegroupgap': 0},
#                'showlegend': False,
#                'template': '...',
#                'title': {'text': 'Battle Counts for the Top 15 Languages'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'Language'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Count'}, 'type': 'log'}}
# })

# %% [markdown]
# ## Number of Conversation Turns
#
# We also noticed that most counversations only have one turn.

# %%
fig = px.histogram(battles["turn"],
             title=f"Number of Conversation Turns",
             text_auto=True, height=400, log_y=True)
fig.update_layout(xaxis_title="Turns", yaxis_title="Count", showlegend=False)
fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.mypipenv/lib/python3.14/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'bingroup': 'x',
#               'hovertemplate': 'variable=turn<br>value=%{x}<br>count=%{y}<extra></extra>',
#               'legendgroup': 'turn',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': 'turn',
#               'orientation': 'v',
#               'showlegend': True,
#               'texttemplate': '%{value}',
#               'type': 'histogram',
#               'x': {'bdata': ('AQEBAQEBAQEBAQEBAQEBAQMBAQEBAQ' ... 'EEAQEBAQECAwECAwECAQICAQEBAQIB'),
#                     'dtype': 'i1'},
#               'xaxis': 'x',
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'height': 400,
#                'legend': {'title': {'text': 'variable'}, 'tracegroupgap': 0},
#                'showlegend': False,
#                'template': '...',
#                'title': {'text': 'Number of Conversation Turns'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'Turns'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Count'}, 'type': 'log'}}
# })

# %% [markdown]
# ## Pairwise Win Fractions
#
# Finally, we can also compute the pairwise win fractions. However, because each model can play as Model A and as Model B and win in both situations we need to compute the wins in both configurations divided by the number of pairings of each model.

# %%
def compute_pairwise_win_fraction(battles, max_num_models=30):
    # Times each model wins as Model A
    a_win_ptbl = pd.pivot_table(
        battles[battles['winner'] == "model_a"],
        index="model_a", columns="model_b", aggfunc="size", fill_value=0)

    # Table counting times each model wins as Model B
    b_win_ptbl = pd.pivot_table(
        battles[battles['winner'] == "model_b"],
        index="model_a", columns="model_b", aggfunc="size", fill_value=0)

    # Table counting number of A-B pairs
    num_battles_ptbl = pd.pivot_table(battles,
        index="model_a", columns="model_b", aggfunc="size", fill_value=0)

    # Computing the proportion of wins for each model as A and as B
    # against all other models
    row_beats_col_freq = (
        (a_win_ptbl + b_win_ptbl.T) /
        (num_battles_ptbl + num_battles_ptbl.T)
    )

    # Arrange ordering according to proprition of wins
    prop_wins = row_beats_col_freq.mean(axis=1).sort_values(ascending=False)
    prop_wins = prop_wins[:max_num_models]
    model_names = list(prop_wins.keys())
    row_beats_col = row_beats_col_freq.loc[model_names, model_names]
    return row_beats_col

def visualize_pairwise_win_fraction(battles, title, max_num_models=30):
    row_beats_col = compute_pairwise_win_fraction(battles, max_num_models)
    fig = px.imshow(row_beats_col, color_continuous_scale='RdBu',
                    text_auto=".2f", title=title)
    fig.update_layout(xaxis_title=" Model B: Loser",
                  yaxis_title="Model A: Winner",
                  xaxis_side="top", height=900, width=900,
                  title_y=0.07, title_x=0.5)
    fig.update_traces(hovertemplate=
                  "Model A: %{y}<br>Model B: %{x}<br>Fraction of A Wins: %{z}<extra></extra>")

    return fig

# %%
fig = visualize_pairwise_win_fraction(battles_no_ties,
      title = "Fraction of Model A Wins for All Non-tied A vs. B Battles")
fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.mypipenv/lib/python3.14/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'coloraxis': 'coloraxis',
#               'hovertemplate': 'Model A: %{y}<br>Model B: %{x}<br>Fraction of A Wins: %{z}<extra></extra>',
#               'name': '0',
#               'texttemplate': '%{z:.2f}',
#               'type': 'heatmap',
#               'x': array(['gemini-1.5-pro-api-0409-preview', 'chatgpt-4o-latest',
#                           'gpt-3.5-turbo-0314', 'gpt-4-1106-preview', 'gpt-4o-2024-05-13',
#                           'gpt-4-0125-preview', 'gemini-1.5-pro-exp-0801',
#                           'bard-jan-24-gemini-pro', 'gpt-4-turbo-2024-04-09',
#                           'claude-3-opus-20240229', 'gemini-advanced-0514', 'gpt-4-0314',
#                           'claude-1', 'claude-3-5-sonnet-20240620', 'gpt-4o-mini-2024-07-18',
#                           'gemini-1.5-pro-api-0514', 'llama-3.1-405b-instruct',
#                           'yi-large-preview', 'claude-2.0', 'gpt-3.5-turbo-0613',
#                           'claude-3-sonnet-20240229', 'gpt-4o-2024-08-06', 'claude-instant-1',
#                           'gpt-4-0613', 'mistral-large-2407', 'athene-70b-0725',
#                           'gemini-1.5-flash-api-0514', 'mpt-30b-chat', 'llama-3-70b-instruct',
#                           'mistral-medium'], dtype=object),
#               'xaxis': 'x',
#               'y': array(['gemini-1.5-pro-api-0409-preview', 'chatgpt-4o-latest',
#                           'gpt-3.5-turbo-0314', 'gpt-4-1106-preview', 'gpt-4o-2024-05-13',
#                           'gpt-4-0125-preview', 'gemini-1.5-pro-exp-0801',
#                           'bard-jan-24-gemini-pro', 'gpt-4-turbo-2024-04-09',
#                           'claude-3-opus-20240229', 'gemini-advanced-0514', 'gpt-4-0314',
#                           'claude-1', 'claude-3-5-sonnet-20240620', 'gpt-4o-mini-2024-07-18',
#                           'gemini-1.5-pro-api-0514', 'llama-3.1-405b-instruct',
#                           'yi-large-preview', 'claude-2.0', 'gpt-3.5-turbo-0613',
#                           'claude-3-sonnet-20240229', 'gpt-4o-2024-08-06', 'claude-instant-1',
#                           'gpt-4-0613', 'mistral-large-2407', 'athene-70b-0725',
#                           'gemini-1.5-flash-api-0514', 'mpt-30b-chat', 'llama-3-70b-instruct',
#                           'mistral-medium'], dtype=object),
#               'yaxis': 'y',
#               'z': {'bdata': ('AAAAAAAA+P8AAAAAAAD4/wAAAAAAAP' ... 'AAAAAA+P/8LkPhiQrYPwAAAAAAAPj/'),
#                     'dtype': 'f8',
#                     'shape': '30, 30'}}],
#     'layout': {'coloraxis': {'colorscale': [[0.0, 'rgb(103,0,31)'], [0.1,
#                                             'rgb(178,24,43)'], [0.2,
#                                             'rgb(214,96,77)'], [0.3,
#                                             'rgb(244,165,130)'], [0.4,
#                                             'rgb(253,219,199)'], [0.5,
#                                             'rgb(247,247,247)'], [0.6,
#                                             'rgb(209,229,240)'], [0.7,
#                                             'rgb(146,197,222)'], [0.8,
#                                             'rgb(67,147,195)'], [0.9,
#                                             'rgb(33,102,172)'], [1.0,
#                                             'rgb(5,48,97)']]},
#                'height': 900,
#                'template': '...',
#                'title': {'text': 'Fraction of Model A Wins for All Non-tied A vs. B Battles', 'x': 0.5, 'y': 0.07},
#                'width': 900,
#                'xaxis': {'anchor': 'y',
#                          'constrain': 'domain',
#                          'domain': [0.0, 1.0],
#                          'scaleanchor': 'y',
#                          'side': 'top',
#                          'title': {'text': ' Model B: Loser'}},
#                'yaxis': {'anchor': 'x',
#                          'autorange': 'reversed',
#                          'constrain': 'domain',
#                          'domain': [0.0, 1.0],
#                          'title': {'text': 'Model A: Winner'}}}
# })

# %% [markdown]
# ## Preliminary Ranking
#
# Using just the average win rate against all other models we can already compute an estimated leaderboard.
# However, this method may not be as scalable as the Elo rating system that we will use later because this method requires data from all model combinations.

# %%
row_beats_col_freq = compute_pairwise_win_fraction(battles_no_ties)
fig = px.bar(row_beats_col_freq.mean(axis=1).sort_values(ascending=False),
             title="Average Win Rate Against All Other Models (Assuming Uniform Sampling and No Ties)",
             text_auto=".2f")
fig.update_layout(yaxis_title="Average Win Rate", xaxis_title="Model",
                  showlegend=False)
fig
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.mypipenv/lib/python3.14/site-packages/IPython/core/formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File ~/.mypipenv/lib/python3.14/site-packages/plotly/io/_renderers.py:415, in show(fig, renderer, validate, **kwargs)
#     410     raise ValueError(
#     411         "Mime type rendering requires ipython but it is not installed"
#     412     )
#     414 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 415     raise ValueError(
#     416         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     417     )
#     419 display_jupyter_version_warnings()
#     421 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'variable=0<br>model_a=%{x}<br>value=%{y}<extra></extra>',
#               'legendgroup': '0',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': '0',
#               'orientation': 'v',
#               'showlegend': True,
#               'textposition': 'auto',
#               'texttemplate': '%{y:.2f}',
#               'type': 'bar',
#               'x': array(['chatgpt-4o-latest', 'gemini-1.5-pro-exp-0801', 'gpt-4o-2024-05-13',
#                           'gemini-1.5-pro-api-0409-preview', 'gemini-advanced-0514',
#                           'gpt-4-1106-preview', 'claude-3-opus-20240229',
#                           'claude-3-5-sonnet-20240620', 'bard-jan-24-gemini-pro',
#                           'gpt-4o-mini-2024-07-18', 'gemini-1.5-pro-api-0514',
#                           'gpt-4-0125-preview', 'gpt-4-turbo-2024-04-09', 'gpt-4o-2024-08-06',
#                           'llama-3.1-405b-instruct', 'athene-70b-0725', 'mistral-large-2407',
#                           'yi-large-preview', 'gpt-4-0314', 'claude-1',
#                           'gemini-1.5-flash-api-0514', 'gpt-3.5-turbo-0314',
#                           'claude-3-sonnet-20240229', 'claude-2.0', 'llama-3-70b-instruct',
#                           'claude-instant-1', 'gpt-3.5-turbo-0613', 'mistral-medium',
#                           'gpt-4-0613', 'mpt-30b-chat'], dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': ('0MurPh/U5D8/LCBIWmjjP3iJVXmXJu' ... 'TbwHTB2D8aFwO7c37YPz0pZPg5vM0/'),
#                     'dtype': 'f8'},
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'legend': {'title': {'text': 'variable'}, 'tracegroupgap': 0},
#                'showlegend': False,
#                'template': '...',
#                'title': {'text': 'Average Win Rate Against All Other Models (Assuming Uniform Sampling and No Ties)'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'Model'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Average Win Rate'}}}
# })

# %% [markdown]
# #Elo Ratings
#
# The [Elo rating system ](https://en.wikipedia.org/wiki/Elo_rating_system)is a method for calculating the relative skill levels of players, which has been widely adopted in chess and other competitive games. The difference in the ratings between two players serves as a predictor of the outcome of a match. The Elo rating system works well for our case because we have multiple models and we run pairwise battles between them.
# In this section, we present different methods for calculating Elo ratings.

# %% [markdown]
# ### Compute Ratings
# We first use the online linear update algorithm to compute Elo ratings.
# We choose a small K-factor of 4 to make the Elo ratings more stable and less biased towards recent games.

# %%
def compute_online_elo(battles, K=4, SCALE=400, BASE=10, INIT_RATING=1000):
    rating = defaultdict(lambda: INIT_RATING)

    for rd, model_a, model_b, winner in battles[['model_a', 'model_b', 'winner']].itertuples():
        ra = rating[model_a]
        rb = rating[model_b]
        ea = 1 / (1 + BASE ** ((rb - ra) / SCALE))
        eb = 1 / (1 + BASE ** ((ra - rb) / SCALE))
        if winner == "model_a":
            sa = 1
        elif winner == "model_b":
            sa = 0
        elif winner == "tie" or winner == "tie (bothbad)":
            sa = 0.5
        else:
            raise Exception(f"unexpected vote {winner}")
        rating[model_a] += K * (sa - ea)
        rating[model_b] += K * (1 - sa - eb)

    # calibrate llama-13b to 800
    delta = (800-rating["llama-13b"])
    for model in battles["model_a"].unique():
        rating[model] += delta

    return rating

# %%
def preety_print_model_ratings(ratings):
    df = pd.DataFrame([
        [n, ratings[n]] for n in ratings.keys()
    ], columns=["Model", "Elo rating"]).sort_values("Elo rating", ascending=False).reset_index(drop=True)
    # df["Elo rating"] = (df["Elo rating"] + 0.5).astype(int)
    df.index = df.index + 1
    return df

online_elo_ratings = compute_online_elo(battles)
preety_print_model_ratings(online_elo_ratings)
# Out:
#                                Model  Elo rating
# 1    gemini-1.5-pro-api-0409-preview     1106.87
# 2            gemini-1.5-pro-exp-0801     1074.94
# 3                  chatgpt-4o-latest     1073.74
# 4                 gpt-3.5-turbo-0314     1051.02
# 5             bard-jan-24-gemini-pro     1041.26
# ..                               ...         ...
# 125                      chatglm3-6b      814.55
# 126                 oasst-pythia-12b      812.39
# 127                        llama-13b      800.00
# 128                   fastchat-t5-3b      794.37
# 129                     dolly-v2-12b      781.44
#
# [129 rows x 2 columns]

# %% [markdown]
# However, even with a small K-factor, we still found this online update algorithm to be unstable.
#
# To demonstrate it, we recompute Elo rating by using the reversed game order and observe significant difference due to online update of Elo which biases the recent games.

# %%
def preety_print_two_ratings(ratings_1, ratings_2, column_names):
    df = pd.DataFrame([
        [n, ratings_1[n], ratings_2[n]] for n in ratings_1.keys()
    ], columns=["Model", column_names[0], column_names[1]]).sort_values(column_names[0], ascending=False).reset_index(drop=True)
    df[column_names[0]] = (df[column_names[0]] + 0.5).astype(int)
    df[column_names[1]] = (df[column_names[1]] + 0.5).astype(int)
    df.index = df.index + 1
    return df

elo_mle_ratings_reverse = compute_online_elo(battles.iloc[::-1])
preety_print_two_ratings(online_elo_ratings,
                         elo_mle_ratings_reverse,
                         column_names=["Elo rating", "Elo rating with reverse order"])
# Out:
#                                Model  Elo rating  \
# 1    gemini-1.5-pro-api-0409-preview        1107
# 2            gemini-1.5-pro-exp-0801        1075
# 3                  chatgpt-4o-latest        1074
# 4                 gpt-3.5-turbo-0314        1051
# 5             bard-jan-24-gemini-pro        1041
# ..                               ...         ...
# 125                      chatglm3-6b         815
# 126                 oasst-pythia-12b         812
# 127                        llama-13b         800
# 128                   fastchat-t5-3b         794
# 129                     dolly-v2-12b         781
#
#      Elo rating with reverse order
# 1                             1112
# 2                             1086
# 3                             1151
# 4                             1162
# 5                             1155
# ..                             ...
# 125                            893
# 126                            907
# 127                            800
# 128                            863
# 129                            833
#
# [129 rows x 3 columns]

# %% [markdown]
# ### [Bradley-Terry model](https://en.wikipedia.org/wiki/Bradley%E2%80%93Terry_model)
#
# In the context of LLM evaluation, models can be assumed to be static. In this case, we can directly fit the ratings with Bradley-Terry model, which produce significantly stable ratings. Here we provide an implementation with logistic regression.

# %%
def compute_mle_elo(
    df, SCALE=400, BASE=10, INIT_RATING=1000, sample_weight=None
):
    from sklearn.linear_model import LogisticRegression
    ptbl_a_win = pd.pivot_table(
        df[df["winner"] == "model_a"],
        index="model_a",
        columns="model_b",
        aggfunc="size",
        fill_value=0,
    )
    # if no tie, create a zero matrix
    if sum(df["winner"].isin(["tie", "tie (bothbad)"])) == 0:
        ptbl_tie = pd.DataFrame(0, index=ptbl_a_win.index, columns=ptbl_a_win.columns)
    else:
        ptbl_tie = pd.pivot_table(
            df[df["winner"].isin(["tie", "tie (bothbad)"])],
            index="model_a",
            columns="model_b",
            aggfunc="size",
            fill_value=0,
        )
        ptbl_tie = ptbl_tie + ptbl_tie.T

    ptbl_b_win = pd.pivot_table(
        df[df["winner"] == "model_b"],
        index="model_a",
        columns="model_b",
        aggfunc="size",
        fill_value=0,
    )
    ptbl_win = ptbl_a_win * 2 + ptbl_b_win.T * 2 + ptbl_tie

    models = pd.Series(np.arange(len(ptbl_win.index)), index=ptbl_win.index)

    p = len(models)
    X = np.zeros([p * (p - 1) * 2, p])
    Y = np.zeros(p * (p - 1) * 2)

    cur_row = 0
    sample_weights = []
    for m_a in ptbl_win.index:
        for m_b in ptbl_win.columns:
            if m_a == m_b:
                continue
            # if nan skip
            if math.isnan(ptbl_win.loc[m_a, m_b]) or math.isnan(ptbl_win.loc[m_b, m_a]):
                continue
            X[cur_row, models[m_a]] = +math.log(BASE)
            X[cur_row, models[m_b]] = -math.log(BASE)
            Y[cur_row] = 1.0
            sample_weights.append(ptbl_win.loc[m_a, m_b])

            X[cur_row + 1, models[m_a]] = math.log(BASE)
            X[cur_row + 1, models[m_b]] = -math.log(BASE)
            Y[cur_row + 1] = 0.0
            sample_weights.append(ptbl_win.loc[m_b, m_a])
            cur_row += 2
    X = X[:cur_row]
    Y = Y[:cur_row]

    lr = LogisticRegression(fit_intercept=False, penalty=None, tol=1e-6)
    lr.fit(X, Y, sample_weight=sample_weights)
    elo_scores = SCALE * lr.coef_[0] + INIT_RATING
    if "mixtral-8x7b-instruct-v0.1" in models.index:
        elo_scores += 1114 - elo_scores[models["mixtral-8x7b-instruct-v0.1"]]
    return pd.Series(elo_scores, index=models.index).sort_values(ascending=False)

# %%
elo_mle_ratings = compute_mle_elo(battles)
preety_print_model_ratings(elo_mle_ratings)
# Out:
# /home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
#                           Model  Elo rating
# 1             chatgpt-4o-latest     1315.16
# 2       gemini-1.5-pro-exp-0801     1298.43
# 3             gpt-4o-2024-05-13     1285.83
# 4        gpt-4o-mini-2024-07-18     1274.85
# 5    claude-3-5-sonnet-20240620     1270.98
# ..                          ...         ...
# 125                  chatglm-6b      878.99
# 126              fastchat-t5-3b      868.29
# 127     stablelm-tuned-alpha-7b      839.69
# 128                dolly-v2-12b      822.08
# 129                   llama-13b      798.92
#
# [129 rows x 2 columns]

# %% [markdown]
# ### Compute Bootstrap Confidence Interavals for BT Scores
#
# We can further use bootstrap to estimate the confidence intervals as well.

# %%
def get_bootstrap_result(battles, func_compute_elo, num_round):
    rows = []
    for i in tqdm(range(num_round), desc="bootstrap"):
        rows.append(func_compute_elo(battles.sample(frac=1.0, replace=True)))
    df = pd.DataFrame(rows)
    return df[df.median().sort_values(ascending=False).index]

# %%
BOOTSTRAP_ROUNDS = 100

np.random.seed(42)
bootstrap_elo_lu = get_bootstrap_result(battles, compute_mle_elo, BOOTSTRAP_ROUNDS)
# Out:
# bootstrap:   0%|                                                                                                      | 0/100 [00:00<?, ?it/s]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:   1%|▉                                                                                             | 1/100 [00:04<06:40,  4.05s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:   2%|█▉                                                                                            | 2/100 [00:08<06:38,  4.07s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:   3%|██▊                                                                                           | 3/100 [00:12<06:36,  4.08s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:   4%|███▊                                                                                          | 4/100 [00:16<06:38,  4.15s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:   5%|████▋                                                                                         | 5/100 [00:20<06:41,  4.23s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:   6%|█████▋                                                                                        | 6/100 [00:25<06:36,  4.22s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:   7%|██████▌                                                                                       | 7/100 [00:29<06:31,  4.21s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:   8%|███████▌                                                                                      | 8/100 [00:33<06:28,  4.22s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:   9%|████████▍                                                                                     | 9/100 [00:37<06:24,  4.22s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:  10%|█████████▎                                                                                   | 10/100 [00:41<06:17,  4.20s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:  11%|██████████▏                                                                                  | 11/100 [00:46<06:12,  4.19s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:  12%|███████████▏                                                                                 | 12/100 [00:50<06:09,  4.19s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:  13%|████████████                                                                                 | 13/100 [00:54<06:03,  4.18s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:  14%|█████████████                                                                                | 14/100 [00:58<05:59,  4.18s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:  15%|█████████████▉                                                                               | 15/100 [01:02<05:58,  4.22s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:  16%|██████████████▉                                                                              | 16/100 [01:07<05:56,  4.24s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:  17%|███████████████▊                                                                             | 17/100 [01:11<06:02,  4.36s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:  18%|████████████████▋                                                                            | 18/100 [01:16<05:57,  4.36s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:  19%|█████████████████▋                                                                           | 19/100 [01:20<05:55,  4.39s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:  20%|██████████████████▌                                                                          | 20/100 [01:24<05:46,  4.33s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:  21%|███████████████████▌                                                                         | 21/100 [01:28<05:38,  4.28s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(
# bootstrap:  22%|████████████████████▍                                                                        | 22/100 [01:33<05:35,  4.30s/it]/home/madison/.mypipenv/lib/python3.14/site-packages/sklearn/linear_model/_logistic.py:1135: FutureWarning: 'penalty' was deprecated in version 1.8 and will be removed in 1.10. To avoid this warning, leave 'penalty' set to its default value and use 'l1_ratio' or 'C' instead. Use l1_ratio=0 instead of penalty='l2', l1_ratio=1 instead of penalty='l1', and C=np.inf instead of penalty=None.
#   warnings.warn(

# %%
def visualize_bootstrap_scores(df, title):
    bars = pd.DataFrame(dict(
        lower = df.quantile(.025),
        rating = df.quantile(.5),
        upper = df.quantile(.975))).reset_index(names="model").sort_values("rating", ascending=False)
    bars['error_y'] = bars['upper'] - bars["rating"]
    bars['error_y_minus'] = bars['rating'] - bars["lower"]
    bars['rating_rounded'] = np.round(bars['rating'], 2)
    fig = px.scatter(bars, x="model", y="rating", error_y="error_y",
                     error_y_minus="error_y_minus", text="rating_rounded",
                     title=title)
    fig.update_layout(xaxis_title="Model", yaxis_title="Rating",
                      height=600)
    return fig

fig = visualize_bootstrap_scores(bootstrap_elo_lu, "Bootstrap of MLE Elo Rating Estimates")
fig

# %% [markdown]
# We previously apply bootstrapping on the online Elo to obtain stabler ratings.

# %%
np.random.seed(42)
bootstrap_online_elo = get_bootstrap_result(battles, compute_online_elo, BOOTSTRAP_ROUNDS)

# %% [markdown]
# We can see the bootstrapping medians obtained by both methods are similar.

# %%
preety_print_two_ratings(bootstrap_elo_lu.quantile(.5),
                         bootstrap_online_elo.quantile(.5),
                         column_names=["Bootstrap Median of BT", "Bootstrap Median of Online Elo"])

# %% [markdown]
# However, online Elo's confidence intervals are significantly larger than the BT.

# %%
fig = visualize_bootstrap_scores(bootstrap_online_elo, "Bootstrap of Online Elo Rating Estimates")
fig

# %% [markdown]
# ### Predict Win Rates
# Utilizing Elo ratings allows us to predict win probabilities. By comparing the predicted win rates with the actual win rates, we can gain insight into the accuracy and quality of the Elo rating system.

# %%
def predict_win_rate(elo_ratings, SCALE=400, BASE=10, INIT_RATING=1000):
    names = sorted(list(elo_ratings.keys()))
    wins = defaultdict(lambda: defaultdict(lambda: 0))
    for a in names:
        for b in names:
            ea = 1 / (1 + BASE ** ((elo_ratings[b] - elo_ratings[a]) / SCALE))
            wins[a][b] = ea
            wins[b][a] = 1 - ea

    data = {
        a: [wins[a][b] if a != b else np.NAN for b in names]
        for a in names
    }

    df = pd.DataFrame(data, index=names)
    df.index.name = "model_a"
    df.columns.name = "model_b"
    return df.T

# %%
win_rate = predict_win_rate(dict(bootstrap_elo_lu.quantile(0.5)))
ordered_models = win_rate.mean(axis=1).sort_values(ascending=False).index
ordered_models = ordered_models[:30]
fig = px.imshow(win_rate.loc[ordered_models, ordered_models],
                color_continuous_scale='RdBu', text_auto=".2f",
                title="Predicted Win Rate Using Elo Ratings for Model A in an A vs. B Battle")
fig.update_layout(xaxis_title="Model B",
                  yaxis_title="Model A",
                  xaxis_side="top", height=900, width=900,
                  title_y=0.07, title_x=0.5)
fig.update_traces(hovertemplate=
                  "Model A: %{y}<br>Model B: %{x}<br>Win Rate: %{z}<extra></extra>")
fig

# %% [markdown]
# ### Compute Bootstrap Confidence Intervals Assuming Uniform Sampling
#
# We also study how the ratings will change if we only sample an equal number of battles for each model pair.

# %%
def sample_battle_even(battles, n_per_battle):
    groups = battles.groupby(["model_a", "model_b"], as_index=False)
    resampled = (groups
                 .apply(lambda grp: grp.sample(n_per_battle, replace=True))
                 .reset_index(drop=True))
    return resampled

# %%
num_samples = 50
battles_even = sample_battle_even(battles, num_samples)
pd.pivot_table(battles_even, index="model_a", columns="model_b", aggfunc="size", fill_value=0)

# %%
# Sampling Battles Evenly
def get_bootstrap_even_sample(battles, n_per_battle, func_compute_elo, num_round=BOOTSTRAP_ROUNDS):
    rows = []
    for n in tqdm(range(num_round), desc="sampling battles evenly"):
        resampled = sample_battle_even(battles, n_per_battle)
        rows.append(func_compute_elo(resampled))
    df = pd.DataFrame(rows)
    return df[df.median().sort_values(ascending=False).index]

# %%
print("number of samples per battle pair:", num_samples)
bootstrap_even_lu = get_bootstrap_even_sample(battles, num_samples, compute_mle_elo, num_round=100)

# %%
fig = visualize_bootstrap_scores(bootstrap_even_lu, f"Bootstrap of MLE Elo Estimates - Even sample")
fig

# %% [markdown]
# # Language-specific Leaderboards
# We present two language-specific leaderboards, by isolating the chat data into two subsets based on the language: (1) English-only and (2) Non-English.

# %% [markdown]
# ## English-only

# %%
english_only_battles = battles[battles["language"] == "English"]
elo_ratings = compute_mle_elo(english_only_battles)
pd.DataFrame(elo_ratings)

# %% [markdown]
# ## Non-English

# %%
non_english_battles = battles[battles["language"] != "English"]
elo_ratings = compute_mle_elo(non_english_battles)
pd.DataFrame(elo_ratings)

# %% [markdown]
# # Links

# %% [markdown]
# Some good resources to learn more about Elo rating systems:
# - Elo rating system https://en.wikipedia.org/wiki/Elo_rating_system
# - Bradley-Terry model https://en.wikipedia.org/wiki/Bradley%E2%80%93Terry_model
# - An introduction video https://www.youtube.com/watch?v=AsYfbmp0To0
# - A FiveThirtyEight article https://fivethirtyeight.com/methodology/how-our-nfl-predictions-work/
